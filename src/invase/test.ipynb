# %%
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

from method import INVASE

X, y = load_iris(return_X_y=True, as_frame = True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

## Load the model
model = XGBClassifier()

model.fit(X_train.values, y_train.values)

#print accuracy
print("Accuracy: ", model.score(X_test, y_test))

## Load INVASE
explainer = INVASE(
    model, 
    X_train, 
    y_train, 
    n_epoch=1000, 
    prefit = True, # the model is already trained
    n_folds=1,
    method = 'normal',
)

## Explain
explainer.explain(X_test.head(5))
# Out:
# Accuracy:  0.9666666666666667
#  60%|██████    | 600/1000 [00:09<00:06, 65.55it/s]
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.099478          0.087497           0.628574          0.313126
# 1           0.119348          0.104194           0.628793          0.303008
# 2           0.112758          0.097252           0.642929          0.302971
# 3           0.117582          0.059458           0.744274          0.156349
# 4           0.134684          0.083005           0.676745          0.200773

# %%
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

from method import INVASE

X, y = load_iris(return_X_y=True, as_frame = True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

## Load the model
model = XGBClassifier()

model.fit(X_train.values, y_train.values)

#print accuracy
print("Accuracy: ", model.score(X_test, y_test))

## Load INVASE
explainer = INVASE(
    model, 
    X_train, 
    y_train, 
    n_epoch=1000, 
    prefit = True, # the model is already trained
    n_folds=1,
    method = 'optimized',
)

## Explain
explainer.explain(X_test.head(5))
# Out:
# Accuracy:  0.9333333333333333
#  60%|██████    | 600/1000 [00:37<00:24, 16.07it/s]
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.045561          0.022069           0.938713          0.108633
# 1           0.037204          0.016961           0.949318          0.104867
# 2           0.046456          0.034612           0.756899          0.501230
# 3           0.073776          0.056041           0.716135          0.531586
# 4           0.080832          0.061372           0.722940          0.452513
